# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
scores_finances  = pd.read_json('resources/scores_finances.json')

# %%
schools  = pd.read_json('resources/texas-school.json')

# %%
df = pd.DataFrame(scores_finances)

df2 = pd.DataFrame(schools)

# %%
df = df.rename(columns=lambda x: x.replace(' ', '_'))
df

# %%
df['Campus_Name'] = df['Campus_Name'].str.lower()

# %%
df2.drop(labels=['CountyNumber', 'CountyName', 'RegionNumber', 'DistrictNumber',
       'DistrictType', 'DistrictStreetAddress', 'DistrictCity',
       'DistrictState', 'DistrictZip', 'DistrictSiteStreetAddress',
       'DistrictSiteCity', 'DistrictSiteState', 'DistrictSiteZip',
       'DistrictPhone', 'DistrictFax', 'DistrictEmailAddress',
       'DistrictWebPageAddress', 'DistrictSuperintendent',
       'DistrictEnrollmentasofOct2014', 'SchoolNumber',
       'InstructionType', 'CharterType', 'SchoolCity',
       'SchoolState', 'SchoolZip', 'SchoolSiteStreetAddress', 'SchoolSiteCity',
       'SchoolSiteState', 'SchoolSiteZip', 'SchoolPhone', 'SchoolFax',
       'SchoolEmailAddress', 'SchoolWebPageAddress', 'SchoolPrincipal',
       'GradeRange', 'SchoolEnrollmentasofOct2014', 'SchoolStatus',
       'SchoolStatusDate', 'UpdateDate', 'GeocodeQualityType','SchoolStreetAddress'], axis=1, inplace=True)

# %%
df2.dropna()

# %%
df2.rename(columns={'SchoolName': 'Campus_Name', 'DistrictName':'District_Name'}, inplace=True)

# %%
df2['District_Name'] = df2['District_Name'].str.lower()
df2['Campus_Name'] = df2['Campus_Name'].str.lower()

# %%
df2

# %%
school_info = pd.merge(df, df2, how = "left", on=['District_Name', 'Campus_Name'] )

# %%
school_info = school_info.dropna()

# %%
school_info.to_csv('finance_scores_coordinates.csv', index=True)

# %%
expenses = pd.read_csv('resources/expidenture_data.csv')
expenses_df = pd.DataFrame(expenses)
expenses_df
# Out:
#                                         District Number  District Name  \
# 0                                                   NaN            NaN
# 1                                                001902     CAYUGA ISD
# 2                                                001903    ELKHART ISD
# 3                                                001904  FRANKSTON ISD
# 4                                                001906     NECHES ISD
# ...                                                 ...            ...
# 1319                                                NaN    State Total
# 1320                                                NaN            NaN
# 1321  1. Total Operating expenditures All funds are ...            NaN
# 1322                                                NaN            NaN
# 1323  2. Membership is the total number of students ...            NaN
#
#                                        2005-2006                Unnamed: 3  \
# 0     Total  Operating Expenditures, All Funds 1  Enrollment (membership)2
# 1                                     $4,419,577                       582
# 2                                     $8,655,605                     1,294
# 3                                     $6,475,854                       797
# 4                                     $2,641,035                       329
# ...                                          ...                       ...
# 1319                             $33,734,468,768                $4,504,627
# 1320                                         NaN                       NaN
# 1321                                         NaN                       NaN
# 1322                                         NaN                       NaN
# 1323                                         NaN                       NaN
#
#                                         Unnamed: 4  \
# 0     All Funds Operating Expenditures per Student
# 1                                           $7,594
# 2                                           $6,689
# 3                                           $8,125
# 4                                           $8,027
# ...                                            ...
# 1319                                        $7,489
# 1320                                           NaN
# 1321                                           NaN
# 1322                                           NaN
# 1323                                           NaN
#
#                                        2006-2007                Unnamed: 6  \
# 0     Total  Operating Expenditures, All Funds 1  Enrollment (membership)2
# 1                                     $4,693,094                       569
# 2                                     $8,955,664                     1,319
# 3                                     $6,584,942                       789
# 4                                     $2,721,193                       352
# ...                                          ...                       ...
# 1319                             $35,890,138,442                 4,576,678
# 1320                                         NaN                       NaN
# 1321                                         NaN                       NaN
# 1322                                         NaN                       NaN
# 1323                                         NaN                       NaN
#
#                                         Unnamed: 7  \
# 0     All Funds Operating Expenditures per Student
# 1                                           $8,248
# 2                                           $6,790
# 3                                           $8,346
# 4                                           $7,731
# ...                                            ...
# 1319                                        $7,842
# 1320                                           NaN
# 1321                                           NaN
# 1322                                           NaN
# 1323                                           NaN
#
#                                        2007-2008                Unnamed: 9  \
# 0     Total  Operating Expenditures, All Funds 1  Enrollment (membership)2
# 1                                     $7,417,070                       580
# 2                                     $9,559,209                     1,375
# 3                                     $7,085,955                       801
# 4                                     $2,981,438                       361
# ...                                          ...                       ...
# 1319                             $38,805,399,085                 4,651,012
# 1320                                         NaN                       NaN
# 1321                                         NaN                       NaN
# 1322                                         NaN                       NaN
# 1323                                         NaN                       NaN
#
#       ...                                   Unnamed: 34  \
# 0     ...  All Funds Operating Expenditures per Student
# 1     ...                                       $14,924
# 2     ...                                        $8,953
# 3     ...                                        $9,170
# 4     ...                                       $10,626
# ...   ...                                           ...
# 1319  ...                                        $9,308
# 1320  ...                                           NaN
# 1321  ...                                           NaN
# 1322  ...                                           NaN
# 1323  ...                                           NaN
#
#                                        2016-2017               Unnamed: 36  \
# 0     Total  Operating Expenditures, All Funds 1  Enrollment (membership)2
# 1                                     $8,331,442                       576
# 2                                    $11,147,631                     1,267
# 3                                     $8,218,507                       846
# 4                                     $3,979,099                       377
# ...                                          ...                       ...
# 1319                             $50,324,982,318                 5,341,009
# 1320                                         NaN                       NaN
# 1321                                         NaN                       NaN
# 1322                                         NaN                       NaN
# 1323                                         NaN                       NaN
#
#                                        Unnamed: 37  \
# 0     All Funds Operating Expenditures per Student
# 1                                          $14,464
# 2                                           $8,798
# 3                                           $9,715
# 4                                          $10,555
# ...                                            ...
# 1319                                        $9,422
# 1320                                           NaN
# 1321                                           NaN
# 1322                                           NaN
# 1323                                           NaN
#
#                                        2017-2018               Unnamed: 39  \
# 0     Total  Operating Expenditures, All Funds 1  Enrollment (membership)2
# 1                                     $8,325,066                       575
# 2                                    $11,503,115                     1,233
# 3                                     $8,406,173                       872
# 4                                     $4,046,814                       360
# ...                                          ...                       ...
# 1319                             $52,435,381,781                 5,384,847
# 1320                                         NaN                       NaN
# 1321                                         NaN                       NaN
# 1322                                         NaN                       NaN
# 1323                                         NaN                       NaN
#
#                                        Unnamed: 40  \
# 0     All Funds Operating Expenditures per Student
# 1                                          $14,478
# 2                                           $9,329
# 3                                           $9,640
# 4                                          $11,241
# ...                                            ...
# 1319                                        $9,738
# 1320                                           NaN
# 1321                                           NaN
# 1322                                           NaN
# 1323                                           NaN
#
#                                        2018-2019               Unnamed: 42  \
# 0     Total  Operating Expenditures, All Funds 1  Enrollment (membership)2
# 1                                     $8,558,886                       564
# 2                                    $11,696,322                     1,254
# 3                                     $8,802,724                       803
# 4                                     $4,021,890                       366
# ...                                          ...                       ...
# 1319                             $53,692,440,166                 5,416,161
# 1320                                         NaN                       NaN
# 1321                                         NaN                       NaN
# 1322                                         NaN                       NaN
# 1323                                         NaN                       NaN
#
#                                        Unnamed: 43
# 0     All Funds Operating Expenditures per Student
# 1                                          $15,175
# 2                                           $9,327
# 3                                          $10,962
# 4                                          $10,989
# ...                                            ...
# 1319                                        $9,913
# 1320                                           NaN
# 1321                                           NaN
# 1322                                           NaN
# 1323                                           NaN
#
# [1324 rows x 44 columns]

# %%
expenses_df.drop(labels = ['District Number', '2005-2006', 'Unnamed: 3',
       'Unnamed: 4', '2006-2007', 'Unnamed: 6', 'Unnamed: 7', '2007-2008',
       'Unnamed: 9', 'Unnamed: 10', '2008-2009', 'Unnamed: 12', 'Unnamed: 13',
       '2009-2010', 'Unnamed: 15', 'Unnamed: 16', '2010-2011', 'Unnamed: 18',
       'Unnamed: 19', '2011-2012', 'Unnamed: 21', 'Unnamed: 22', '2012-2013',
       'Unnamed: 24', 'Unnamed: 25', '2013-2014', 'Unnamed: 27', 'Unnamed: 28',
       '2014-2015', 'Unnamed: 30', 'Unnamed: 31', '2015-2016', 'Unnamed: 33',
       'Unnamed: 34', '2016-2017', 'Unnamed: 36', 'Unnamed: 37', '2017-2018',
       'Unnamed: 39', 'Unnamed: 40'], axis=1, inplace=True)

# %%
expenses_df.rename(columns={'District Name': 'District_Name', '2018-2019':'Total_Operating_Revenue', 'Unnamed: 42': 'Student_Count', 'Unnamed: 43': "per_student_budget" }, inplace=True)

# %%
expenses_df.dropna()
# Out:
#           District_Name Total_Operating_Revenue Student_Count  \
# 1            CAYUGA ISD                 8558886           564
# 2           ELKHART ISD                11696322          1254
# 3         FRANKSTON ISD                 8802724           803
# 4            NECHES ISD                 4021890           366
# 5         PALESTINE ISD                36374344          3389
# ...                 ...                     ...           ...
# 1315          OLNEY ISD                 9119890           677
# 1316  ZAPATA COUNTY ISD                37533118          3509
# 1317   CRYSTAL CITY ISD                20471866          1923
# 1318       LA PRYOR ISD                 6538687           503
# 1319        State Total             53692440166       5416161
#
#      per_student_budget
# 1               $15,175
# 2                $9,327
# 3               $10,962
# 4               $10,989
# 5               $10,733
# ...                 ...
# 1315            $13,471
# 1316            $10,696
# 1317            $10,646
# 1318            $12,999
# 1319             $9,913
#
# [1201 rows x 4 columns]

# %%
expenses_df

# %%
expenses_df['Total_Operating_Revenue'] = expenses_df['Total_Operating_Revenue'].str.replace(',', '').str.replace('$', '')
expenses_df['Student_Count'] = expenses_df['Student_Count'].str.replace(',', '')

# %%
expenses_df
# Out:
#       District_Name                    Total_Operating_Revenue  \
# 0               NaN  Total  Operating Expenditures All Funds 1
# 1        CAYUGA ISD                                    8558886
# 2       ELKHART ISD                                   11696322
# 3     FRANKSTON ISD                                    8802724
# 4        NECHES ISD                                    4021890
# ...             ...                                        ...
# 1319    State Total                                53692440166
# 1320            NaN                                        NaN
# 1321            NaN                                        NaN
# 1322            NaN                                        NaN
# 1323            NaN                                        NaN
#
#                  Student_Count                            per_student_budget
# 0     Enrollment (membership)2  All Funds Operating Expenditures per Student
# 1                          564                                       $15,175
# 2                         1254                                        $9,327
# 3                          803                                       $10,962
# 4                          366                                       $10,989
# ...                        ...                                           ...
# 1319                   5416161                                        $9,913
# 1320                       NaN                                           NaN
# 1321                       NaN                                           NaN
# 1322                       NaN                                           NaN
# 1323                       NaN                                           NaN
#
# [1324 rows x 4 columns]

# %%
expenses_df['Total_Operating_Revenue'] = expenses_df['Total_Operating_Revenue'].astype(int)
expenses_df['Student_Count'] = expenses_df['Student_Count'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 expenses_df['Total_Operating_Revenue'] = expenses_df['Total_Operating_Revenue'].astype(int)
#       2 expenses_df['Student_Count'] = expenses_df['Student_Count'].astype(int)
#
# File c:\Users\mclel\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\mclel\anaconda3\envs\dev\lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File c:\Users\mclel\anaconda3\envs\dev\lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\mclel\anaconda3\envs\dev\lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File c:\Users\mclel\anaconda3\envs\dev\lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File c:\Users\mclel\anaconda3\envs\dev\lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\mclel\anaconda3\envs\dev\lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Total  Operating Expenditures All Funds 1'

# %%
# Define a function to determine marker size based on total operating revenue
def get_marker_size(revenue):
    if revenue < 5000000:
        return 5
    elif 5000000 <= revenue < 10000000:
        return 10
    elif 10000000 <= revenue < 50000000:
        return 15
    elif 50000000 <= revenue < 100000000:
        return 20
    elif 100000000 <= revenue < 500000000:
        return 25
    else:
        return 30

# Define a function to determine marker color based on student count based on UIL conferences 6A-1A
def get_marker_color(student_count):
    if student_count >= 2275:
        return 'red'
    elif 1315 <= student_count <= 2274:
        return 'purple'
    elif 545 <= student_count <= 1314:
        return 'blue'
    elif 254 <= student_count <= 544:
        return 'yellow'
    elif 105 <= student_count <= 253:
        return 'orange'
    else:
        return 'green'


map = folium.Map(location=[29.7604, -95.3698], zoom_start=6)
# Create a feature group for the markers
    
marker_group = folium.FeatureGroup(name='Markers')

# Iterate through the DataFrame to create markers with varying size and color
for idx, row in expenses_df.iterrows():
    size = get_marker_size(row['Total_Operating_Revenue'])
    color = get_marker_color(row['Student_Count'])
    popup_text = f"ISD Name: {row['District_Name']}<br>Revenue: ${row['Total_Operating_Revenue']:,}<br>Student Count: {row['Student_Count']:,}"
    marker = folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                                  radius=size,
                                  color=color,
                                  fill=True,
                                  fill_color=color,
                                  fill_opacity=0.5,
                                  popup=popup_text,
                                  clickable=True)
    marker.add_to(marker_group)

# Add the feature group to the map
marker_group.add_to(map)

# Add a layer control to the map
folium.LayerControl().add_to(map)

# Define legend HTML
legend_html = """
<script type="text/javascript">
    var legend = L.control({position: 'bottomleft'});

    legend.onAdd = function (map) {
        var div = L.DomUtil.create('div', 'info legend');
        div.innerHTML += '<b>Legend</b><br>';
        div.innerHTML += '<i style="background: red">&nbsp;&nbsp;</i> 6A: 2275 and above<br>';
        div.innerHTML += '<i style="background: purple">&nbsp;&nbsp;</i> 5A: 1315 - 2274<br>';
        div.innerHTML += '<i style="background: blue">&nbsp;&nbsp;</i> 4A: 545 - 1314<br>';
        div.innerHTML += '<i style="background: yellow">&nbsp;&nbsp;</i> 3A: 254 - 544<br>';
        div.innerHTML += '<i style="background: orange">&nbsp;&nbsp;</i> 2A: 105 - 253<br>';
        div.innerHTML += '<i style="background: green">&nbsp;&nbsp;</i> 1A: Below 105<br>';
        return div;
    };

    legend.addTo(map);
</script>
"""

# Add the legend HTML to the map's HTML
map.get_root().html.add_child(folium.Element(legend_html))
# Save the map
map.save('map_with_markers_revenue_size_and_student_count_color_updated.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 39
#      37 # Iterate through the DataFrame to create markers with varying size and color
#      38 for idx, row in expenses_df.iterrows():
# ---> 39     size = get_marker_size(row['Total_Operating_Revenue'])
#      40     color = get_marker_color(row['Student_Count'])
#      41     popup_text = f"ISD Name: {row['District_Name']}<br>Revenue: ${row['Total_Operating_Revenue']:,}<br>Student Count: {row['Student_Count']:,}"
#
# Cell In[14], line 3, in get_marker_size(revenue)
#       2 def get_marker_size(revenue):
# ----> 3     if revenue < 5000000:
#       4         return 5
#       5     elif 5000000 <= revenue < 10000000:
#
# TypeError: '<' not supported between instances of 'str' and 'int'
