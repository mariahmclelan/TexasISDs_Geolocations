# %%
# in terminal
'''
mongoimport --type json -d texasSchoolsDB -c scores_finances --drop --jsonArray scores_finances.json
mongoimport --type json -d texasSchoolsDB -c school_info --drop --jsonArray texas-school.json
'''
# Out:
# '\nmongoimport --type json -d texasSchoolsDB -c scores_finances --drop --jsonArray scores_finances.json\nmongoimport --type json -d texasSchoolsDB -c school-info --drop --jsonArray texas-school.json\n'

# %%
from pymongo import MongoClient
import json

# %%
mongo = MongoClient(port=27017)

# %%
for dbname in mongo.list_database_names():
    if dbname == "texasSchoolsDB":
        print(f'{dbname} <----------')
    else:
        print(dbname)
# Out:
# admin
# autosaurus
# classDB
# config
# epa
# fruits_db
# gardenDB
# local
# met
# petsitly_marketing
# texasSchoolsDB <----------
# travel_db
# uk_food

# %%
db = mongo["texasSchoolsDB"]

# %%
db.list_collection_names()
# Out:
# ['scores_finances', 'school_info']

# %%
db.scores_finances.find_one()
# Out:
# {'_id': ObjectId('65d8020fa6b25e1e60be7237'),
#  'District Name': 'houston isd',
#  'Year': '2022',
#  'Total Operating Revenue': 2535319349.0,
#  'Student Count': 193727.0,
#  'Campus Name': 'Lamar HS',
#  'County Name': 'Harris County',
#  'Region': '4.0',
#  'Region Name': 'Houston',
#  'ERW': 525.0,
#  'SAT Math': 504.0,
#  'SAT Total': 1029.0,
#  'ACT English': 24.1,
#  'ACT Math': 23.0,
#  'ACT Reading': 26.0,
#  'ACT Science': 23.9,
#  'ACT Compos': 24.4,
#  'per student budget': 13087.0}

# %%
db.school_info.find_one()
# Out:
# {'_id': ObjectId('65dd33e4f86f6bc84f06d3f4'),
#  'CountyNumber': "'001",
#  'CountyName': 'ANDERSON COUNTY',
#  'RegionNumber': "'07",
#  'DistrictNumber': "'001902",
#  'DistrictName': 'CAYUGA ISD',
#  'DistrictType': 'INDEPENDENT',
#  'DistrictStreetAddress': 'P O BOX 427',
#  'DistrictCity': 'CAYUGA',
#  'DistrictState': 'TX',
#  'DistrictZip': '75832-0427',
#  'DistrictSiteStreetAddress': '17750 N US HWY 287',
#  'DistrictSiteCity': 'TENNESSEE COLONY',
#  'DistrictSiteState': 'TX',
#  'DistrictSiteZip': '75861',
#  'DistrictPhone': '(903) 928-2102',
#  'DistrictFax': '(903) 928-2646',
#  'DistrictEmailAddress': 'admin@cayuga.esc7.net',
#  'DistrictWebPageAddress': 'www.cayuga.esc7.net',
#  'DistrictSuperintendent': 'DR RICK WEBB   ',
#  'DistrictEnrollmentasofOct2014': '577',
#  'SchoolNumber': "'001902041",
#  'SchoolName': 'CAYUGA MIDDLE',
#  'InstructionType': 'REGULAR INSTRUCTIONAL',
#  'CharterType': '',
#  'SchoolStreetAddress': 'P O BOX 427',
#  'SchoolCity': 'CAYUGA',
#  'SchoolState': 'TX',
#  'SchoolZip': '75832-0427',
#  'SchoolSiteStreetAddress': '17750 N US HWY 287',
#  'SchoolSiteCity': 'TENNESSEE COLONY',
#  'SchoolSiteState': 'TX',
#  'SchoolSiteZip': '75861',
#  'SchoolPhone': '(903) 928-2699 ext:4001',
#  'SchoolFax': '(903) 928-2646',
#  'SchoolEmailAddress': 'admin@cayuga.esc7.net',
#  'SchoolWebPageAddress': 'www.cayuga.esc7.net',
#  'SchoolPrincipal': 'MRS SHERRI MCINNIS   ',
#  'GradeRange': "'06-08",
#  'SchoolEnrollmentasofOct2014': '120',
#  'SchoolStatus': 'Active',
#  'SchoolStatusDate': '1996-03-11',
#  'UpdateDate': '2015-03-14T05:34:57',
#  'GeocodeQualityType': 'Manual ',
#  'Latitude': '31.922572',
#  'Longitude': '-95.973648'}

# %%
scores_finances = db.scores_finances

# %%
scores_finances.update_many({}, [ {'$set': {"SAT Math": {'$toDouble': "$SAT Math"}}} ])
scores_finances.update_many({}, [ {'$set': {"Total Operating Revenue": {'$toDouble': "$Total Operating Revenue"}}} ])
scores_finances.update_many({}, [ {'$set': {"Student Count": {'$toDouble': "$Student Count"}}} ])
scores_finances.update_many({}, [ {'$set': {"ERW": {'$toDouble': "$ERW"}}} ])
scores_finances.update_many({}, [ {'$set': {"SAT Total": {'$toDouble': "$SAT Total"}}} ])
scores_finances.update_many({}, [ {'$set': {"ACT English": {'$toDouble': "$ACT English"}}} ])
scores_finances.update_many({}, [ {'$set': {"ACT Math": {'$toDouble': "$ACT Math"}}} ])
scores_finances.update_many({}, [ {'$set': {"ACT Reading": {'$toDouble': "$ACT Reading"}}} ])
scores_finances.update_many({}, [ {'$set': {"ACT Science": {'$toDouble': "$ACT Science"}}} ])
scores_finances.update_many({}, [ {'$set': {"ACT Compos": {'$toDouble': "$ACT Compos"}}} ])
scores_finances.update_many({}, [ {'$set': {"per student budget": {'$toDouble': "$per student budget"}}} ])

# %%
query = {'SAT Math': 504.0}

results = scores_finances.find(query)

[result for result in results]
# Out:
# [{'_id': ObjectId('65d8020fa6b25e1e60be7237'),
#   'District Name': 'houston isd',
#   'Year': '2022',
#   'Total Operating Revenue': 2535319349.0,
#   'Student Count': 193727.0,
#   'Campus Name': 'Lamar HS',
#   'County Name': 'Harris County',
#   'Region': '4.0',
#   'Region Name': 'Houston',
#   'ERW': 525.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1029.0,
#   'ACT English': 24.1,
#   'ACT Math': 23.0,
#   'ACT Reading': 26.0,
#   'ACT Science': 23.9,
#   'ACT Compos': 24.4,
#   'per student budget': 13087.0},
#  {'_id': ObjectId('65d8020fa6b25e1e60be72fc'),
#   'District Name': 'garland isd',
#   'Year': '2022',
#   'Total Operating Revenue': 619901249.0,
#   'Student Count': 52960.0,
#   'Campus Name': 'N Garland HS',
#   'County Name': 'Dallas County',
#   'Region': '10.0',
#   'Region Name': 'Richardson',
#   'ERW': 498.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1002.0,
#   'ACT English': 20.1,
#   'ACT Math': 20.4,
#   'ACT Reading': 21.8,
#   'ACT Science': 20.5,
#   'ACT Compos': 20.8,
#   'per student budget': 11705.0},
#  {'_id': ObjectId('65d8020fa6b25e1e60be740b'),
#   'District Name': 'bryan isd',
#   'Year': '2022',
#   'Total Operating Revenue': 195788852.0,
#   'Student Count': 16005.0,
#   'Campus Name': 'Bryan Collegiate HS',
#   'County Name': 'Brazos County',
#   'Region': '6.0',
#   'Region Name': 'Huntsville',
#   'ERW': 525.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1029.0,
#   'ACT English': 17.3,
#   'ACT Math': 17.9,
#   'ACT Reading': 19.7,
#   'ACT Science': 19.4,
#   'ACT Compos': 18.7,
#   'per student budget': 12232.0},
#  {'_id': ObjectId('65d8020fa6b25e1e60be750b'),
#   'District Name': 'kennedale isd',
#   'Year': '2022',
#   'Total Operating Revenue': 33734663.0,
#   'Student Count': 2836.0,
#   'Campus Name': 'Kennedale HS',
#   'County Name': 'Tarrant County',
#   'Region': '11.0',
#   'Region Name': 'Fort Worth',
#   'ERW': 526.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1030.0,
#   'ACT English': 19.8,
#   'ACT Math': 19.9,
#   'ACT Reading': 21.5,
#   'ACT Science': 21.9,
#   'ACT Compos': 20.9,
#   'per student budget': 11895.0},
#  {'_id': ObjectId('65d8020fa6b25e1e60be7586'),
#   'District Name': 'whitney isd',
#   'Year': '2022',
#   'Total Operating Revenue': 19817508.0,
#   'Student Count': 1474.0,
#   'Campus Name': 'Whitney HS',
#   'County Name': 'Hill County',
#   'Region': '12.0',
#   'Region Name': 'Waco',
#   'ERW': 501.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1006.0,
#   'ACT English': 19.0,
#   'ACT Math': 19.6,
#   'ACT Reading': 19.2,
#   'ACT Science': 20.7,
#   'ACT Compos': 19.7,
#   'per student budget': 13444.0},
#  {'_id': ObjectId('65d8020fa6b25e1e60be75f4'),
#   'District Name': 'new waverly isd',
#   'Year': '2022',
#   'Total Operating Revenue': 14468899.0,
#   'Student Count': 994.0,
#   'Campus Name': 'New Waverly HS',
#   'County Name': 'Walker County',
#   'Region': '6.0',
#   'Region Name': 'Huntsville',
#   'ERW': 507.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1010.0,
#   'ACT English': 22.0,
#   'ACT Math': 21.6,
#   'ACT Reading': 25.1,
#   'ACT Science': 21.9,
#   'ACT Compos': 22.9,
#   'per student budget': 14556.0},
#  {'_id': ObjectId('65d80210a6b25e1e60be7638'),
#   'District Name': 'garrison isd',
#   'Year': '2022',
#   'Total Operating Revenue': 10564419.0,
#   'Student Count': 748.0,
#   'Campus Name': 'Garrison HS',
#   'County Name': 'Nacogdoches County',
#   'Region': '7.0',
#   'Region Name': 'Kilgore',
#   'ERW': 511.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1016.0,
#   'ACT English': 17.1,
#   'ACT Math': 18.1,
#   'ACT Reading': 19.1,
#   'ACT Science': 19.1,
#   'ACT Compos': 18.5,
#   'per student budget': 14123.0},
#  {'_id': ObjectId('65d80210a6b25e1e60be7683'),
#   'District Name': 'ropes isd',
#   'Year': '2022',
#   'Total Operating Revenue': 7526657.0,
#   'Student Count': 514.0,
#   'Campus Name': 'Ropes School',
#   'County Name': 'Hockley County',
#   'Region': '17.0',
#   'Region Name': 'Lubbock',
#   'ERW': 512.0,
#   'SAT Math': 504.0,
#   'SAT Total': 1016.0,
#   'ACT English': 18.7,
#   'ACT Math': 18.9,
#   'ACT Reading': 20.5,
#   'ACT Science': 20.2,
#   'ACT Compos': 19.7,
#   'per student budget': 14643.0}]

# %%
school_info = db.school_info

# %%
query = {"CountyName": "SAN PATRICIO COUNTY"}

results = school_info.find(query)

[result for result in results]
# Out:
# [{'_id': ObjectId('65dd33e5f86f6bc84f06f0f8'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205901",
#   'DistrictName': 'ARANSAS PASS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictCity': 'ARANSAS PASS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78336-2442',
#   'DistrictSiteStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictSiteCity': 'ARANSAS PASS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78336-2442',
#   'DistrictPhone': '(361) 758-3466',
#   'DistrictFax': '(361) 758-2962',
#   'DistrictEmailAddress': 'mkemp@apisd.org',
#   'DistrictWebPageAddress': 'www.apisd.org',
#   'DistrictSuperintendent': 'MR MARK KEMP   ',
#   'DistrictEnrollmentasofOct2014': '1849',
#   'SchoolNumber': "'205901002",
#   'SchoolName': 'ARANSAS PASS JJAEP',
#   'InstructionType': 'JJAEP INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '244 W HARRISON BLVD',
#   'SchoolCity': 'ARANSAS PASS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78336',
#   'SchoolSiteStreetAddress': '244 W HARRISON BLVD',
#   'SchoolSiteCity': 'ARANSAS PASS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78336-2442',
#   'SchoolPhone': '(361) 758-3466',
#   'SchoolFax': '(361) 758-2962',
#   'SchoolEmailAddress': 'ravery@apisd.org',
#   'SchoolWebPageAddress': 'apisd.org',
#   'SchoolPrincipal': '    ',
#   'GradeRange': "'06-12 UG",
#   'SchoolEnrollmentasofOct2014': '0',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '2003-06-11',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.90386708',
#   'Longitude': '-97.14876352'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f0f9'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205901",
#   'DistrictName': 'ARANSAS PASS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictCity': 'ARANSAS PASS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78336-2442',
#   'DistrictSiteStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictSiteCity': 'ARANSAS PASS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78336-2442',
#   'DistrictPhone': '(361) 758-3466',
#   'DistrictFax': '(361) 758-2962',
#   'DistrictEmailAddress': 'mkemp@apisd.org',
#   'DistrictWebPageAddress': 'www.apisd.org',
#   'DistrictSuperintendent': 'MR MARK KEMP   ',
#   'DistrictEnrollmentasofOct2014': '1849',
#   'SchoolNumber': "'205901101",
#   'SchoolName': 'H T FAULK EARLY CHILDHOOD SCHOOL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '430 S 8TH ST',
#   'SchoolCity': 'ARANSAS PASS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78336-4099',
#   'SchoolSiteStreetAddress': '430 S 8TH ST',
#   'SchoolSiteCity': 'ARANSAS PASS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78336-4099',
#   'SchoolPhone': '(361) 758-3141',
#   'SchoolFax': '(361) 758-5493',
#   'SchoolEmailAddress': 'dpatterson@apisd.org',
#   'SchoolWebPageAddress': 'apisd.org',
#   'SchoolPrincipal': 'DAVID PATTERSON   ',
#   'GradeRange': "'EE-01",
#   'SchoolEnrollmentasofOct2014': '351',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.90660672',
#   'Longitude': '-97.15580592'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f0fa'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205901",
#   'DistrictName': 'ARANSAS PASS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictCity': 'ARANSAS PASS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78336-2442',
#   'DistrictSiteStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictSiteCity': 'ARANSAS PASS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78336-2442',
#   'DistrictPhone': '(361) 758-3466',
#   'DistrictFax': '(361) 758-2962',
#   'DistrictEmailAddress': 'mkemp@apisd.org',
#   'DistrictWebPageAddress': 'www.apisd.org',
#   'DistrictSuperintendent': 'MR MARK KEMP   ',
#   'DistrictEnrollmentasofOct2014': '1849',
#   'SchoolNumber': "'205901102",
#   'SchoolName': 'W A KIEBERGER EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '748 W GOODNIGHT AVE',
#   'SchoolCity': 'ARANSAS PASS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78336-3599',
#   'SchoolSiteStreetAddress': '748 W GOODNIGHT AVE',
#   'SchoolSiteCity': 'ARANSAS PASS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78336-3599',
#   'SchoolPhone': '(361) 758-3113',
#   'SchoolFax': '(361) 758-3605',
#   'SchoolEmailAddress': 'jpinto@apisd.org',
#   'SchoolWebPageAddress': 'apisd.org',
#   'SchoolPrincipal': 'JOY PINTO   ',
#   'GradeRange': "'02-03",
#   'SchoolEnrollmentasofOct2014': '288',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.90616115',
#   'Longitude': '-97.15280147'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f0fb'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205901",
#   'DistrictName': 'ARANSAS PASS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictCity': 'ARANSAS PASS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78336-2442',
#   'DistrictSiteStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictSiteCity': 'ARANSAS PASS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78336-2442',
#   'DistrictPhone': '(361) 758-3466',
#   'DistrictFax': '(361) 758-2962',
#   'DistrictEmailAddress': 'mkemp@apisd.org',
#   'DistrictWebPageAddress': 'www.apisd.org',
#   'DistrictSuperintendent': 'MR MARK KEMP   ',
#   'DistrictEnrollmentasofOct2014': '1849',
#   'SchoolNumber': "'205901001",
#   'SchoolName': 'ARANSAS PASS H S',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '450 S AVE A',
#   'SchoolCity': 'ARANSAS PASS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78336-4699',
#   'SchoolSiteStreetAddress': '450 S AVE A',
#   'SchoolSiteCity': 'ARANSAS PASS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78336-4699',
#   'SchoolPhone': '(361) 758-3248',
#   'SchoolFax': '(361) 758-3251',
#   'SchoolEmailAddress': 'lizharris@apisd.org',
#   'SchoolWebPageAddress': 'apisd.org',
#   'SchoolPrincipal': 'MR WAYNE BENNETT   ',
#   'GradeRange': "'09-12",
#   'SchoolEnrollmentasofOct2014': '497',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.9127706',
#   'Longitude': '-97.16637971'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f0fc'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205902",
#   'DistrictName': 'GREGORY-PORTLAND ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '608 COLLEGE ST',
#   'DistrictCity': 'PORTLAND',
#   'DistrictState': 'TX',
#   'DistrictZip': '78374',
#   'DistrictSiteStreetAddress': '608 COLLEGE ST',
#   'DistrictSiteCity': 'PORTLAND',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78374',
#   'DistrictPhone': '(361) 777-1091 ext:1018',
#   'DistrictFax': '(361) 777-1093',
#   'DistrictEmailAddress': 'chartley@g-pisd.org',
#   'DistrictWebPageAddress': 'www.g-pisd.org',
#   'DistrictSuperintendent': 'DR PAUL CLORE   ',
#   'DistrictEnrollmentasofOct2014': '4597',
#   'SchoolNumber': "'205902001",
#   'SchoolName': 'GREGORY-PORTLAND H S',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '4601 WILDCAT DR',
#   'SchoolCity': 'PORTLAND',
#   'SchoolState': 'TX',
#   'SchoolZip': '78374-2899',
#   'SchoolSiteStreetAddress': '4601 WILDCAT DR',
#   'SchoolSiteCity': 'PORTLAND',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78374-2899',
#   'SchoolPhone': '(361) 777-4251 ext:6029',
#   'SchoolFax': '(361) 777-4272',
#   'SchoolEmailAddress': 'bcade@g-pisd.org',
#   'SchoolWebPageAddress': 'www.g-pisd.org',
#   'SchoolPrincipal': 'MRS BARBARA CADE   ',
#   'GradeRange': "'09-12",
#   'SchoolEnrollmentasofOct2014': '1357',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.903465',
#   'Longitude': '-97.323398'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f0fd'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205902",
#   'DistrictName': 'GREGORY-PORTLAND ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '608 COLLEGE ST',
#   'DistrictCity': 'PORTLAND',
#   'DistrictState': 'TX',
#   'DistrictZip': '78374',
#   'DistrictSiteStreetAddress': '608 COLLEGE ST',
#   'DistrictSiteCity': 'PORTLAND',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78374',
#   'DistrictPhone': '(361) 777-1091 ext:1018',
#   'DistrictFax': '(361) 777-1093',
#   'DistrictEmailAddress': 'chartley@g-pisd.org',
#   'DistrictWebPageAddress': 'www.g-pisd.org',
#   'DistrictSuperintendent': 'DR PAUL CLORE   ',
#   'DistrictEnrollmentasofOct2014': '4597',
#   'SchoolNumber': "'205902041",
#   'SchoolName': 'GREGORY-PORTLAND J H',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '4600 WILDCAT DR',
#   'SchoolCity': 'PORTLAND',
#   'SchoolState': 'TX',
#   'SchoolZip': '78374-2899',
#   'SchoolSiteStreetAddress': '4600 WILDCAT DR',
#   'SchoolSiteCity': 'PORTLAND',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78374-2899',
#   'SchoolPhone': '(361) 777-4042 ext:5055',
#   'SchoolFax': '(361) 643-3187',
#   'SchoolEmailAddress': 'xbarrera@g-pisd.org',
#   'SchoolWebPageAddress': 'www.g-pisd.org',
#   'SchoolPrincipal': 'MR XAVIER BARRERA   ',
#   'GradeRange': "'07-08",
#   'SchoolEnrollmentasofOct2014': '729',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.892864',
#   'Longitude': '-97.320555'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f0fe'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205902",
#   'DistrictName': 'GREGORY-PORTLAND ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '608 COLLEGE ST',
#   'DistrictCity': 'PORTLAND',
#   'DistrictState': 'TX',
#   'DistrictZip': '78374',
#   'DistrictSiteStreetAddress': '608 COLLEGE ST',
#   'DistrictSiteCity': 'PORTLAND',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78374',
#   'DistrictPhone': '(361) 777-1091 ext:1018',
#   'DistrictFax': '(361) 777-1093',
#   'DistrictEmailAddress': 'chartley@g-pisd.org',
#   'DistrictWebPageAddress': 'www.g-pisd.org',
#   'DistrictSuperintendent': 'DR PAUL CLORE   ',
#   'DistrictEnrollmentasofOct2014': '4597',
#   'SchoolNumber': "'205902101",
#   'SchoolName': 'AUSTIN EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '308 N GREGORY AVE',
#   'SchoolCity': 'GREGORY',
#   'SchoolState': 'TX',
#   'SchoolZip': '78359-0338',
#   'SchoolSiteStreetAddress': '308 N GREGORY AVE',
#   'SchoolSiteCity': 'GREGORY',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78359-0338',
#   'SchoolPhone': '(361) 777-4252 ext:2000',
#   'SchoolFax': '(361) 777-4261',
#   'SchoolEmailAddress': 'shartman@g-pisd.org',
#   'SchoolWebPageAddress': 'www.g-pisd.org',
#   'SchoolPrincipal': 'GLORIA DORNAK   ',
#   'GradeRange': "'EE-04",
#   'SchoolEnrollmentasofOct2014': '475',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.925668',
#   'Longitude': '-97.287896'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f0ff'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205901",
#   'DistrictName': 'ARANSAS PASS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictCity': 'ARANSAS PASS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78336-2442',
#   'DistrictSiteStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictSiteCity': 'ARANSAS PASS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78336-2442',
#   'DistrictPhone': '(361) 758-3466',
#   'DistrictFax': '(361) 758-2962',
#   'DistrictEmailAddress': 'mkemp@apisd.org',
#   'DistrictWebPageAddress': 'www.apisd.org',
#   'DistrictSuperintendent': 'MR MARK KEMP   ',
#   'DistrictEnrollmentasofOct2014': '1849',
#   'SchoolNumber': "'205901104",
#   'SchoolName': 'CHARLIE MARSHALL EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2300 MCMULLEN LN',
#   'SchoolCity': 'ARANSAS PASS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78336-9999',
#   'SchoolSiteStreetAddress': '2300 MCMULLEN LN',
#   'SchoolSiteCity': 'ARANSAS PASS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78336-9999',
#   'SchoolPhone': '(361) 758-3455',
#   'SchoolFax': '(361) 758-3046',
#   'SchoolEmailAddress': 'chouston@apisd.org',
#   'SchoolWebPageAddress': 'apisd.org',
#   'SchoolPrincipal': 'DR JON C HOUSTON   ',
#   'GradeRange': "'04-05",
#   'SchoolEnrollmentasofOct2014': '290',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '1996-01-01',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.91458737',
#   'Longitude': '-97.17424885'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f100'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205902",
#   'DistrictName': 'GREGORY-PORTLAND ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '608 COLLEGE ST',
#   'DistrictCity': 'PORTLAND',
#   'DistrictState': 'TX',
#   'DistrictZip': '78374',
#   'DistrictSiteStreetAddress': '608 COLLEGE ST',
#   'DistrictSiteCity': 'PORTLAND',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78374',
#   'DistrictPhone': '(361) 777-1091 ext:1018',
#   'DistrictFax': '(361) 777-1093',
#   'DistrictEmailAddress': 'chartley@g-pisd.org',
#   'DistrictWebPageAddress': 'www.g-pisd.org',
#   'DistrictSuperintendent': 'DR PAUL CLORE   ',
#   'DistrictEnrollmentasofOct2014': '4597',
#   'SchoolNumber': "'205902103",
#   'SchoolName': 'EAST CLIFF EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '200 FULTON ST',
#   'SchoolCity': 'PORTLAND',
#   'SchoolState': 'TX',
#   'SchoolZip': '78374-1399',
#   'SchoolSiteStreetAddress': '200 FULTON ST',
#   'SchoolSiteCity': 'PORTLAND',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78374-1399',
#   'SchoolPhone': '(361) 777-4255 ext:2242',
#   'SchoolFax': '(361) 777-3207',
#   'SchoolEmailAddress': 'amunoz@g-pisd.org',
#   'SchoolWebPageAddress': 'www.g-pisd.org',
#   'SchoolPrincipal': 'MRS ALMA MUNOZ   ',
#   'GradeRange': "'EE KG-04",
#   'SchoolEnrollmentasofOct2014': '399',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.87860544',
#   'Longitude': '-97.3135117'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f101'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205901",
#   'DistrictName': 'ARANSAS PASS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictCity': 'ARANSAS PASS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78336-2442',
#   'DistrictSiteStreetAddress': '2300 MCMULLEN LANE STE #600',
#   'DistrictSiteCity': 'ARANSAS PASS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78336-2442',
#   'DistrictPhone': '(361) 758-3466',
#   'DistrictFax': '(361) 758-2962',
#   'DistrictEmailAddress': 'mkemp@apisd.org',
#   'DistrictWebPageAddress': 'www.apisd.org',
#   'DistrictSuperintendent': 'MR MARK KEMP   ',
#   'DistrictEnrollmentasofOct2014': '1849',
#   'SchoolNumber': "'205901041",
#   'SchoolName': 'A C BLUNT MIDDLE',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2103 DEMORY LN',
#   'SchoolCity': 'ARANSAS PASS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78336-4612',
#   'SchoolSiteStreetAddress': '2103 DEMORY LN',
#   'SchoolSiteCity': 'ARANSAS PASS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78336-4612',
#   'SchoolPhone': '(361) 758-2711',
#   'SchoolFax': '(361) 758-4690',
#   'SchoolEmailAddress': 'mrose@apisd.org',
#   'SchoolWebPageAddress': 'apisd.org',
#   'SchoolPrincipal': 'MR MARK KEMP   ',
#   'GradeRange': "'06-08",
#   'SchoolEnrollmentasofOct2014': '423',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.91811866',
#   'Longitude': '-97.17324155'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f102'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205902",
#   'DistrictName': 'GREGORY-PORTLAND ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '608 COLLEGE ST',
#   'DistrictCity': 'PORTLAND',
#   'DistrictState': 'TX',
#   'DistrictZip': '78374',
#   'DistrictSiteStreetAddress': '608 COLLEGE ST',
#   'DistrictSiteCity': 'PORTLAND',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78374',
#   'DistrictPhone': '(361) 777-1091 ext:1018',
#   'DistrictFax': '(361) 777-1093',
#   'DistrictEmailAddress': 'chartley@g-pisd.org',
#   'DistrictWebPageAddress': 'www.g-pisd.org',
#   'DistrictSuperintendent': 'DR PAUL CLORE   ',
#   'DistrictEnrollmentasofOct2014': '4597',
#   'SchoolNumber': "'205902104",
#   'SchoolName': 'ANDREWS EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '1100 LANG RD',
#   'SchoolCity': 'PORTLAND',
#   'SchoolState': 'TX',
#   'SchoolZip': '78374-2023',
#   'SchoolSiteStreetAddress': '1100 LANG RD',
#   'SchoolSiteCity': 'PORTLAND',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78374-2023',
#   'SchoolPhone': '(361) 777-4048 ext:2433',
#   'SchoolFax': '(361) 643-0775',
#   'SchoolEmailAddress': 'meddins@g-pisd.org',
#   'SchoolWebPageAddress': 'www.g-pisd.org',
#   'SchoolPrincipal': 'MRS JANA TARKINGTON   ',
#   'GradeRange': "'EE KG-04",
#   'SchoolEnrollmentasofOct2014': '348',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '1979-07-20',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.89744499',
#   'Longitude': '-97.33997633'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f103'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205902",
#   'DistrictName': 'GREGORY-PORTLAND ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '608 COLLEGE ST',
#   'DistrictCity': 'PORTLAND',
#   'DistrictState': 'TX',
#   'DistrictZip': '78374',
#   'DistrictSiteStreetAddress': '608 COLLEGE ST',
#   'DistrictSiteCity': 'PORTLAND',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78374',
#   'DistrictPhone': '(361) 777-1091 ext:1018',
#   'DistrictFax': '(361) 777-1093',
#   'DistrictEmailAddress': 'chartley@g-pisd.org',
#   'DistrictWebPageAddress': 'www.g-pisd.org',
#   'DistrictSuperintendent': 'DR PAUL CLORE   ',
#   'DistrictEnrollmentasofOct2014': '4597',
#   'SchoolNumber': "'205902105",
#   'SchoolName': 'GREGORY-PORTLAND INT',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '4200 WILDCAT DR',
#   'SchoolCity': 'PORTLAND',
#   'SchoolState': 'TX',
#   'SchoolZip': '78374-2908',
#   'SchoolSiteStreetAddress': '4200 WILDCAT DR',
#   'SchoolSiteCity': 'PORTLAND',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78374-2908',
#   'SchoolPhone': '(361) 777-4258 ext:3060',
#   'SchoolFax': '(361) 643-8193',
#   'SchoolEmailAddress': 'lvilla@g-pisd.org',
#   'SchoolWebPageAddress': 'www.g-pisd.org',
#   'SchoolPrincipal': 'MRS LETICIA VILLA   ',
#   'GradeRange': "'05-06",
#   'SchoolEnrollmentasofOct2014': '670',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '1993-07-01',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.89018164',
#   'Longitude': '-97.31986772'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f104'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205903",
#   'DistrictName': 'INGLESIDE ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1320',
#   'DistrictCity': 'INGLESIDE',
#   'DistrictState': 'TX',
#   'DistrictZip': '78362-1313',
#   'DistrictSiteStreetAddress': '2664 SAN ANGELO',
#   'DistrictSiteCity': 'INGLESIDE',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78362-1313',
#   'DistrictPhone': '(361) 776-7631 ext:242 ',
#   'DistrictFax': '(361) 776-0267',
#   'DistrictEmailAddress': 'sylvia.elizondo@inglesideisd.org',
#   'DistrictWebPageAddress': 'www.inglesideisd.org',
#   'DistrictSuperintendent': 'MR TROY C MIRCOVICH   ',
#   'DistrictEnrollmentasofOct2014': '2292',
#   'SchoolNumber': "'205903001",
#   'SchoolName': 'INGLESIDE H S',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2807 MUSTANG DR',
#   'SchoolCity': 'INGLESIDE',
#   'SchoolState': 'TX',
#   'SchoolZip': '78362-1313',
#   'SchoolSiteStreetAddress': '2807 MUSTANG DR',
#   'SchoolSiteCity': 'INGLESIDE',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78362-1313',
#   'SchoolPhone': '(361) 776-2712',
#   'SchoolFax': '(361) 776-5200',
#   'SchoolEmailAddress': '',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'MR DANIEL GLOVER   ',
#   'GradeRange': "'09-12",
#   'SchoolEnrollmentasofOct2014': '650',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.87818583',
#   'Longitude': '-97.21989229'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f105'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205902",
#   'DistrictName': 'GREGORY-PORTLAND ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '608 COLLEGE ST',
#   'DistrictCity': 'PORTLAND',
#   'DistrictState': 'TX',
#   'DistrictZip': '78374',
#   'DistrictSiteStreetAddress': '608 COLLEGE ST',
#   'DistrictSiteCity': 'PORTLAND',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78374',
#   'DistrictPhone': '(361) 777-1091 ext:1018',
#   'DistrictFax': '(361) 777-1093',
#   'DistrictEmailAddress': 'chartley@g-pisd.org',
#   'DistrictWebPageAddress': 'www.g-pisd.org',
#   'DistrictSuperintendent': 'DR PAUL CLORE   ',
#   'DistrictEnrollmentasofOct2014': '4597',
#   'SchoolNumber': "'205902102",
#   'SchoolName': 'CLARK EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2250 MEMORIAL PKWY',
#   'SchoolCity': 'PORTLAND',
#   'SchoolState': 'TX',
#   'SchoolZip': '78374-2099',
#   'SchoolSiteStreetAddress': '2250 MEMORIAL PKWY',
#   'SchoolSiteCity': 'PORTLAND',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78374-2099',
#   'SchoolPhone': '(361) 777-4045 ext:2635',
#   'SchoolFax': '(361) 777-4046',
#   'SchoolEmailAddress': 'brister@g-pisd.org',
#   'SchoolWebPageAddress': 'www.g-pisd.org',
#   'SchoolPrincipal': 'MR BOBBY RISTER   ',
#   'GradeRange': "'EE-04",
#   'SchoolEnrollmentasofOct2014': '619',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.89559713',
#   'Longitude': '-97.31879286'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f106'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205903",
#   'DistrictName': 'INGLESIDE ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1320',
#   'DistrictCity': 'INGLESIDE',
#   'DistrictState': 'TX',
#   'DistrictZip': '78362-1313',
#   'DistrictSiteStreetAddress': '2664 SAN ANGELO',
#   'DistrictSiteCity': 'INGLESIDE',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78362-1313',
#   'DistrictPhone': '(361) 776-7631 ext:242 ',
#   'DistrictFax': '(361) 776-0267',
#   'DistrictEmailAddress': 'sylvia.elizondo@inglesideisd.org',
#   'DistrictWebPageAddress': 'www.inglesideisd.org',
#   'DistrictSuperintendent': 'MR TROY C MIRCOVICH   ',
#   'DistrictEnrollmentasofOct2014': '2292',
#   'SchoolNumber': "'205903102",
#   'SchoolName': 'INGLESIDE PRIMARY SCHOOL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2100 ACHIEVEMENT BLVD',
#   'SchoolCity': 'INGLESIDE',
#   'SchoolState': 'TX',
#   'SchoolZip': '78362-1313',
#   'SchoolSiteStreetAddress': '2100 ACHIEVEMENT BLVD',
#   'SchoolSiteCity': 'INGLESIDE',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78362-1313',
#   'SchoolPhone': '(361) 776-3060',
#   'SchoolFax': '(361) 775-2070',
#   'SchoolEmailAddress': '',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'KIMBERLY ALAMO   ',
#   'GradeRange': "'EE-01",
#   'SchoolEnrollmentasofOct2014': '424',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.86147',
#   'Longitude': '-97.207464'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f107'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205903",
#   'DistrictName': 'INGLESIDE ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1320',
#   'DistrictCity': 'INGLESIDE',
#   'DistrictState': 'TX',
#   'DistrictZip': '78362-1313',
#   'DistrictSiteStreetAddress': '2664 SAN ANGELO',
#   'DistrictSiteCity': 'INGLESIDE',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78362-1313',
#   'DistrictPhone': '(361) 776-7631 ext:242 ',
#   'DistrictFax': '(361) 776-0267',
#   'DistrictEmailAddress': 'sylvia.elizondo@inglesideisd.org',
#   'DistrictWebPageAddress': 'www.inglesideisd.org',
#   'DistrictSuperintendent': 'MR TROY C MIRCOVICH   ',
#   'DistrictEnrollmentasofOct2014': '2292',
#   'SchoolNumber': "'205903042",
#   'SchoolName': 'LEON TAYLOR J H',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2739 MUSTANG DR',
#   'SchoolCity': 'INGLESIDE',
#   'SchoolState': 'TX',
#   'SchoolZip': '78362-1313',
#   'SchoolSiteStreetAddress': '2739 MUSTANG DR',
#   'SchoolSiteCity': 'INGLESIDE',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78362-1313',
#   'SchoolPhone': '(361) 776-2232',
#   'SchoolFax': '(361) 776-2192',
#   'SchoolEmailAddress': '',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'MRS HEATHER WAUGH-FREEZE   ',
#   'GradeRange': "'07-08",
#   'SchoolEnrollmentasofOct2014': '344',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '1979-06-08',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.87646382',
#   'Longitude': '-97.21697006'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f108'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205903",
#   'DistrictName': 'INGLESIDE ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1320',
#   'DistrictCity': 'INGLESIDE',
#   'DistrictState': 'TX',
#   'DistrictZip': '78362-1313',
#   'DistrictSiteStreetAddress': '2664 SAN ANGELO',
#   'DistrictSiteCity': 'INGLESIDE',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78362-1313',
#   'DistrictPhone': '(361) 776-7631 ext:242 ',
#   'DistrictFax': '(361) 776-0267',
#   'DistrictEmailAddress': 'sylvia.elizondo@inglesideisd.org',
#   'DistrictWebPageAddress': 'www.inglesideisd.org',
#   'DistrictSuperintendent': 'MR TROY C MIRCOVICH   ',
#   'DistrictEnrollmentasofOct2014': '2292',
#   'SchoolNumber': "'205903103",
#   'SchoolName': 'BLASCHKE/SHELDON ELEMENTARY',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2624 MUSTANG DR',
#   'SchoolCity': 'INGLESIDE',
#   'SchoolState': 'TX',
#   'SchoolZip': '78362-1313',
#   'SchoolSiteStreetAddress': '2624 MUSTANG DR',
#   'SchoolSiteCity': 'INGLESIDE',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78362-1313',
#   'SchoolPhone': '(361) 776-3050',
#   'SchoolFax': '(361) 776-7912',
#   'SchoolEmailAddress': '',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'MRS STEPHANIE MCNEW   ',
#   'GradeRange': "'05-06",
#   'SchoolEnrollmentasofOct2014': '351',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '1979-06-08',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.8761094',
#   'Longitude': '-97.21602156'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f109'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205904",
#   'DistrictName': 'MATHIS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1179',
#   'DistrictCity': 'MATHIS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78368-1179',
#   'DistrictSiteStreetAddress': '602 E SAN PATRICIO AVE',
#   'DistrictSiteCity': 'MATHIS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78368-2429',
#   'DistrictPhone': '(361) 547-3378 ext:1002',
#   'DistrictFax': '(361) 547-4198',
#   'DistrictEmailAddress': 'gnava@mathisisd.org',
#   'DistrictWebPageAddress': 'www.mathisisd.org',
#   'DistrictSuperintendent': 'DR MARIA RODRIGUEZ-CASAS   ',
#   'DistrictEnrollmentasofOct2014': '1708',
#   'SchoolNumber': "'205904041",
#   'SchoolName': 'MATHIS MIDDLE',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1179',
#   'SchoolCity': 'MATHIS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78368-1179',
#   'SchoolSiteStreetAddress': '1627 E SAN PATRICIO AVE',
#   'SchoolSiteCity': 'MATHIS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78368-2264',
#   'SchoolPhone': '(361) 547-3378 ext:4000',
#   'SchoolFax': '(361) 547-4156',
#   'SchoolEmailAddress': 'jgonzalez@mathisisd.org',
#   'SchoolWebPageAddress': 'www.mathisisd.org',
#   'SchoolPrincipal': 'MR JOHN GONZALEZ   ',
#   'GradeRange': "'06-08",
#   'SchoolEnrollmentasofOct2014': '379',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.08458308',
#   'Longitude': '-97.81512373'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f10a'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205904",
#   'DistrictName': 'MATHIS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1179',
#   'DistrictCity': 'MATHIS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78368-1179',
#   'DistrictSiteStreetAddress': '602 E SAN PATRICIO AVE',
#   'DistrictSiteCity': 'MATHIS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78368-2429',
#   'DistrictPhone': '(361) 547-3378 ext:1002',
#   'DistrictFax': '(361) 547-4198',
#   'DistrictEmailAddress': 'gnava@mathisisd.org',
#   'DistrictWebPageAddress': 'www.mathisisd.org',
#   'DistrictSuperintendent': 'DR MARIA RODRIGUEZ-CASAS   ',
#   'DistrictEnrollmentasofOct2014': '1708',
#   'SchoolNumber': "'205904102",
#   'SchoolName': 'MATHIS INT',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1179',
#   'SchoolCity': 'MATHIS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78368-1179',
#   'SchoolSiteStreetAddress': '410 E SAN PATRICIO AVE',
#   'SchoolSiteCity': 'MATHIS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78368-2698',
#   'SchoolPhone': '(361) 547-2472 ext:3001',
#   'SchoolFax': '(361) 547-4119',
#   'SchoolEmailAddress': 'lmorales@mathisisd.org',
#   'SchoolWebPageAddress': 'www.mathisisd.org',
#   'SchoolPrincipal': 'MRS LINDA MORALES   ',
#   'GradeRange': "'03-05",
#   'SchoolEnrollmentasofOct2014': '443',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.09149335',
#   'Longitude': '-97.82469734'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f10b'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205904",
#   'DistrictName': 'MATHIS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1179',
#   'DistrictCity': 'MATHIS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78368-1179',
#   'DistrictSiteStreetAddress': '602 E SAN PATRICIO AVE',
#   'DistrictSiteCity': 'MATHIS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78368-2429',
#   'DistrictPhone': '(361) 547-3378 ext:1002',
#   'DistrictFax': '(361) 547-4198',
#   'DistrictEmailAddress': 'gnava@mathisisd.org',
#   'DistrictWebPageAddress': 'www.mathisisd.org',
#   'DistrictSuperintendent': 'DR MARIA RODRIGUEZ-CASAS   ',
#   'DistrictEnrollmentasofOct2014': '1708',
#   'SchoolNumber': "'205904001",
#   'SchoolName': 'MATHIS H S',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1179',
#   'SchoolCity': 'MATHIS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78368-1179',
#   'SchoolSiteStreetAddress': '1615 E SAN PATRICIO AVE',
#   'SchoolSiteCity': 'MATHIS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78368-1177',
#   'SchoolPhone': '(361) 547-3378 ext:5000',
#   'SchoolFax': '(361) 547-4139',
#   'SchoolEmailAddress': 'aarismendi@mathisisd.org',
#   'SchoolWebPageAddress': 'www.mathisisd.org',
#   'SchoolPrincipal': 'MR ALBERT ARISMENDI   ',
#   'GradeRange': "'09-12",
#   'SchoolEnrollmentasofOct2014': '389',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.08550945',
#   'Longitude': '-97.8163582'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f10c'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205903",
#   'DistrictName': 'INGLESIDE ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1320',
#   'DistrictCity': 'INGLESIDE',
#   'DistrictState': 'TX',
#   'DistrictZip': '78362-1313',
#   'DistrictSiteStreetAddress': '2664 SAN ANGELO',
#   'DistrictSiteCity': 'INGLESIDE',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78362-1313',
#   'DistrictPhone': '(361) 776-7631 ext:242 ',
#   'DistrictFax': '(361) 776-0267',
#   'DistrictEmailAddress': 'sylvia.elizondo@inglesideisd.org',
#   'DistrictWebPageAddress': 'www.inglesideisd.org',
#   'DistrictSuperintendent': 'MR TROY C MIRCOVICH   ',
#   'DistrictEnrollmentasofOct2014': '2292',
#   'SchoolNumber': "'205903104",
#   'SchoolName': 'GILBERT J MIRCOVICH ELEMENTARY',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '2720 BIG OAK LN',
#   'SchoolCity': 'INGLESIDE',
#   'SchoolState': 'TX',
#   'SchoolZip': '78362',
#   'SchoolSiteStreetAddress': '2720 BIG OAK LN',
#   'SchoolSiteCity': 'INGLESIDE',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78362',
#   'SchoolPhone': '(361) 776-1683',
#   'SchoolFax': '(361) 775-0509',
#   'SchoolEmailAddress': '',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'MRS ELIZABETH WILLIAMS   ',
#   'GradeRange': "'02-04",
#   'SchoolEnrollmentasofOct2014': '523',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '1997-07-01',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.87115045',
#   'Longitude': '-97.20349012'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f10d'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205905",
#   'DistrictName': 'ODEM-EDROY ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '1 OWL SQ',
#   'DistrictCity': 'ODEM',
#   'DistrictState': 'TX',
#   'DistrictZip': '78370',
#   'DistrictSiteStreetAddress': '1 OWL SQ',
#   'DistrictSiteCity': 'ODEM',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78370',
#   'DistrictPhone': '(361) 368-8121 ext:223 ',
#   'DistrictFax': '(361) 368-2879',
#   'DistrictEmailAddress': 'gonzalesl@oeisd.org',
#   'DistrictWebPageAddress': 'www.oeisd.org',
#   'DistrictSuperintendent': 'MRS LISA ANE GONZALES   ',
#   'DistrictEnrollmentasofOct2014': '1007',
#   'SchoolNumber': "'205905001",
#   'SchoolName': 'ODEM H S',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '1 OWL SQ',
#   'SchoolCity': 'ODEM',
#   'SchoolState': 'TX',
#   'SchoolZip': '78370',
#   'SchoolSiteStreetAddress': '1 OWL SQ',
#   'SchoolSiteCity': 'ODEM',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78370',
#   'SchoolPhone': '(361) 368-3401 ext:250 ',
#   'SchoolFax': '(361) 368-3781',
#   'SchoolEmailAddress': 'ewinga@oeisd.org',
#   'SchoolWebPageAddress': 'www.oeisd.org',
#   'SchoolPrincipal': 'MRS ANN EWING   ',
#   'GradeRange': "'09-12",
#   'SchoolEnrollmentasofOct2014': '302',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.948805',
#   'Longitude': '-97.591468'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f10e'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205905",
#   'DistrictName': 'ODEM-EDROY ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '1 OWL SQ',
#   'DistrictCity': 'ODEM',
#   'DistrictState': 'TX',
#   'DistrictZip': '78370',
#   'DistrictSiteStreetAddress': '1 OWL SQ',
#   'DistrictSiteCity': 'ODEM',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78370',
#   'DistrictPhone': '(361) 368-8121 ext:223 ',
#   'DistrictFax': '(361) 368-2879',
#   'DistrictEmailAddress': 'gonzalesl@oeisd.org',
#   'DistrictWebPageAddress': 'www.oeisd.org',
#   'DistrictSuperintendent': 'MRS LISA ANE GONZALES   ',
#   'DistrictEnrollmentasofOct2014': '1007',
#   'SchoolNumber': "'205905101",
#   'SchoolName': 'ODEM EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '1 OWL SQ',
#   'SchoolCity': 'ODEM',
#   'SchoolState': 'TX',
#   'SchoolZip': '78370',
#   'SchoolSiteStreetAddress': '1 OWL SQ',
#   'SchoolSiteCity': 'ODEM',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78370',
#   'SchoolPhone': '(361) 368-3881 ext:235 ',
#   'SchoolFax': '(361) 368-2317',
#   'SchoolEmailAddress': 'kieschnickj@oeisd.org',
#   'SchoolWebPageAddress': 'www.oeisd.org',
#   'SchoolPrincipal': 'MRS JANA KIESCHNICK   ',
#   'GradeRange': "'EE-05",
#   'SchoolEnrollmentasofOct2014': '484',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.948644',
#   'Longitude': '-97.593007'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f10f'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205904",
#   'DistrictName': 'MATHIS ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1179',
#   'DistrictCity': 'MATHIS',
#   'DistrictState': 'TX',
#   'DistrictZip': '78368-1179',
#   'DistrictSiteStreetAddress': '602 E SAN PATRICIO AVE',
#   'DistrictSiteCity': 'MATHIS',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78368-2429',
#   'DistrictPhone': '(361) 547-3378 ext:1002',
#   'DistrictFax': '(361) 547-4198',
#   'DistrictEmailAddress': 'gnava@mathisisd.org',
#   'DistrictWebPageAddress': 'www.mathisisd.org',
#   'DistrictSuperintendent': 'DR MARIA RODRIGUEZ-CASAS   ',
#   'DistrictEnrollmentasofOct2014': '1708',
#   'SchoolNumber': "'205904101",
#   'SchoolName': 'MATHIS EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1179',
#   'SchoolCity': 'MATHIS',
#   'SchoolState': 'TX',
#   'SchoolZip': '78368-1179',
#   'SchoolSiteStreetAddress': '315 S DUVAL',
#   'SchoolSiteCity': 'MATHIS',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78368-2699',
#   'SchoolPhone': '(361) 547-4106 ext:2000',
#   'SchoolFax': '(361) 547-4162',
#   'SchoolEmailAddress': 'jdolin@mathisisd.org',
#   'SchoolWebPageAddress': 'www.mathisisd.org',
#   'SchoolPrincipal': 'MR JESSE DOLIN   ',
#   'GradeRange': "'EE-02",
#   'SchoolEnrollmentasofOct2014': '497',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.08993769',
#   'Longitude': '-97.82738162'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f110'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205906",
#   'DistrictName': 'SINTON ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1337',
#   'DistrictCity': 'SINTON',
#   'DistrictState': 'TX',
#   'DistrictZip': '78387-1337',
#   'DistrictSiteStreetAddress': '322 S ARCHER',
#   'DistrictSiteCity': 'SINTON',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78387-2405',
#   'DistrictPhone': '(361) 364-6800',
#   'DistrictFax': '(361) 364-6905',
#   'DistrictEmailAddress': 'pwhitten@sintonisd.net',
#   'DistrictWebPageAddress': 'www.sintonisd.net',
#   'DistrictSuperintendent': 'PARI WHITTEN   ',
#   'DistrictEnrollmentasofOct2014': '2190',
#   'SchoolNumber': "'205906001",
#   'SchoolName': 'SINTON H S',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1337',
#   'SchoolCity': 'SINTON',
#   'SchoolState': 'TX',
#   'SchoolZip': '78387-2799',
#   'SchoolSiteStreetAddress': '400 N PIRATE BLVD',
#   'SchoolSiteCity': 'SINTON',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78387-2799',
#   'SchoolPhone': '(361) 364-6650',
#   'SchoolFax': '(361) 364-6668',
#   'SchoolEmailAddress': 'dsmith@sintonisd.net',
#   'SchoolWebPageAddress': 'www.sintonisd.net',
#   'SchoolPrincipal': 'MR DANIEL SMITH   ',
#   'GradeRange': "'09-12",
#   'SchoolEnrollmentasofOct2014': '657',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.03985529',
#   'Longitude': '-97.49778472'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f111'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205906",
#   'DistrictName': 'SINTON ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1337',
#   'DistrictCity': 'SINTON',
#   'DistrictState': 'TX',
#   'DistrictZip': '78387-1337',
#   'DistrictSiteStreetAddress': '322 S ARCHER',
#   'DistrictSiteCity': 'SINTON',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78387-2405',
#   'DistrictPhone': '(361) 364-6800',
#   'DistrictFax': '(361) 364-6905',
#   'DistrictEmailAddress': 'pwhitten@sintonisd.net',
#   'DistrictWebPageAddress': 'www.sintonisd.net',
#   'DistrictSuperintendent': 'PARI WHITTEN   ',
#   'DistrictEnrollmentasofOct2014': '2190',
#   'SchoolNumber': "'205906002",
#   'SchoolName': 'JUVENILE DETENTION CTR',
#   'InstructionType': 'ALTERNATIVE INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1337',
#   'SchoolCity': 'SINTON',
#   'SchoolState': 'TX',
#   'SchoolZip': '78387-1337',
#   'SchoolSiteStreetAddress': '107 W 5TH ST',
#   'SchoolSiteCity': 'SINTON',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78387-1337',
#   'SchoolPhone': '(361) 364-9508',
#   'SchoolFax': '(361) 364-3707',
#   'SchoolEmailAddress': 'Mtorresgarcia@sintonisd.net',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'MS MARGIE TORRES-GARCIA   ',
#   'GradeRange': "'04-12",
#   'SchoolEnrollmentasofOct2014': '5',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '1994-01-31',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.02832171',
#   'Longitude': '-97.51048104'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f112'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205907",
#   'DistrictName': 'TAFT ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '400 COLLEGE ST',
#   'DistrictCity': 'TAFT',
#   'DistrictState': 'TX',
#   'DistrictZip': '78390-2702',
#   'DistrictSiteStreetAddress': '400 COLLEGE ST',
#   'DistrictSiteCity': 'TAFT',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78390-2702',
#   'DistrictPhone': '(361) 528-2636 ext:2224',
#   'DistrictFax': '(361) 528-2223',
#   'DistrictEmailAddress': 'ncunningham@taftisd.net',
#   'DistrictWebPageAddress': 'www.taftisd.net',
#   'DistrictSuperintendent': 'DR NUGGET CUNNINGHAM   ',
#   'DistrictEnrollmentasofOct2014': '1110',
#   'SchoolNumber': "'205907001",
#   'SchoolName': 'TAFT H S',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '400 COLLEGE ST',
#   'SchoolCity': 'TAFT',
#   'SchoolState': 'TX',
#   'SchoolZip': '78390-2929',
#   'SchoolSiteStreetAddress': '502 RINCON RD',
#   'SchoolSiteCity': 'TAFT',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78390-2929',
#   'SchoolPhone': '(361) 528-2636 ext:2421',
#   'SchoolFax': '(361) 528-3918',
#   'SchoolEmailAddress': 'alopez@taftisd.net',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'MRS ANGEL LOPEZ   ',
#   'GradeRange': "'09-12",
#   'SchoolEnrollmentasofOct2014': '330',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.986585',
#   'Longitude': '-97.388357'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f113'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205906",
#   'DistrictName': 'SINTON ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1337',
#   'DistrictCity': 'SINTON',
#   'DistrictState': 'TX',
#   'DistrictZip': '78387-1337',
#   'DistrictSiteStreetAddress': '322 S ARCHER',
#   'DistrictSiteCity': 'SINTON',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78387-2405',
#   'DistrictPhone': '(361) 364-6800',
#   'DistrictFax': '(361) 364-6905',
#   'DistrictEmailAddress': 'pwhitten@sintonisd.net',
#   'DistrictWebPageAddress': 'www.sintonisd.net',
#   'DistrictSuperintendent': 'PARI WHITTEN   ',
#   'DistrictEnrollmentasofOct2014': '2190',
#   'SchoolNumber': "'205906103",
#   'SchoolName': 'WELDER EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1337',
#   'SchoolCity': 'SINTON',
#   'SchoolState': 'TX',
#   'SchoolZip': '78387',
#   'SchoolSiteStreetAddress': '901 HAMILTON ST',
#   'SchoolSiteCity': 'SINTON',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78387',
#   'SchoolPhone': '(361) 364-6600',
#   'SchoolFax': '(361) 364-6608',
#   'SchoolEmailAddress': 'lrodriguez@sintonisd.net',
#   'SchoolWebPageAddress': 'www.sintonisd.net',
#   'SchoolPrincipal': 'MS LUCI RODRIGUEZ   ',
#   'GradeRange': "'EE-02",
#   'SchoolEnrollmentasofOct2014': '576',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.04238569',
#   'Longitude': '-97.50072926'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f114'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205906",
#   'DistrictName': 'SINTON ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1337',
#   'DistrictCity': 'SINTON',
#   'DistrictState': 'TX',
#   'DistrictZip': '78387-1337',
#   'DistrictSiteStreetAddress': '322 S ARCHER',
#   'DistrictSiteCity': 'SINTON',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78387-2405',
#   'DistrictPhone': '(361) 364-6800',
#   'DistrictFax': '(361) 364-6905',
#   'DistrictEmailAddress': 'pwhitten@sintonisd.net',
#   'DistrictWebPageAddress': 'www.sintonisd.net',
#   'DistrictSuperintendent': 'PARI WHITTEN   ',
#   'DistrictEnrollmentasofOct2014': '2190',
#   'SchoolNumber': "'205906105",
#   'SchoolName': 'SINTON EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1337',
#   'SchoolCity': 'SINTON',
#   'SchoolState': 'TX',
#   'SchoolZip': '78387-1337',
#   'SchoolSiteStreetAddress': '200 S BOWIE AVE',
#   'SchoolSiteCity': 'SINTON',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78387',
#   'SchoolPhone': '(361) 364-6900',
#   'SchoolFax': '(361) 364-6914',
#   'SchoolEmailAddress': 'ltrevino@sintonisd.net',
#   'SchoolWebPageAddress': 'www.sintonisd.net',
#   'SchoolPrincipal': 'MS LORI TREVINO   ',
#   'GradeRange': "'03-05",
#   'SchoolEnrollmentasofOct2014': '497',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': '2003-06-18',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.0342956',
#   'Longitude': '-97.50104704'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f117'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205906",
#   'DistrictName': 'SINTON ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': 'P O BOX 1337',
#   'DistrictCity': 'SINTON',
#   'DistrictState': 'TX',
#   'DistrictZip': '78387-1337',
#   'DistrictSiteStreetAddress': '322 S ARCHER',
#   'DistrictSiteCity': 'SINTON',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78387-2405',
#   'DistrictPhone': '(361) 364-6800',
#   'DistrictFax': '(361) 364-6905',
#   'DistrictEmailAddress': 'pwhitten@sintonisd.net',
#   'DistrictWebPageAddress': 'www.sintonisd.net',
#   'DistrictSuperintendent': 'PARI WHITTEN   ',
#   'DistrictEnrollmentasofOct2014': '2190',
#   'SchoolNumber': "'205906041",
#   'SchoolName': 'E MERLE SMITH MIDDLE',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': 'P O BOX 1337',
#   'SchoolCity': 'SINTON',
#   'SchoolState': 'TX',
#   'SchoolZip': '78387',
#   'SchoolSiteStreetAddress': '900 S SAN PATRICIO AVE',
#   'SchoolSiteCity': 'SINTON',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78387',
#   'SchoolPhone': '(361) 364-6840',
#   'SchoolFax': '(361) 364-6856',
#   'SchoolEmailAddress': 'jdavis@sintonisd.net',
#   'SchoolWebPageAddress': 'www.sintonisd.net',
#   'SchoolPrincipal': 'MS JENNIFER DAVIS   ',
#   'GradeRange': "'06-08",
#   'SchoolEnrollmentasofOct2014': '455',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '28.02764907',
#   'Longitude': '-97.51684248'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f119'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205907",
#   'DistrictName': 'TAFT ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '400 COLLEGE ST',
#   'DistrictCity': 'TAFT',
#   'DistrictState': 'TX',
#   'DistrictZip': '78390-2702',
#   'DistrictSiteStreetAddress': '400 COLLEGE ST',
#   'DistrictSiteCity': 'TAFT',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78390-2702',
#   'DistrictPhone': '(361) 528-2636 ext:2224',
#   'DistrictFax': '(361) 528-2223',
#   'DistrictEmailAddress': 'ncunningham@taftisd.net',
#   'DistrictWebPageAddress': 'www.taftisd.net',
#   'DistrictSuperintendent': 'DR NUGGET CUNNINGHAM   ',
#   'DistrictEnrollmentasofOct2014': '1110',
#   'SchoolNumber': "'205907041",
#   'SchoolName': 'TAFT J H',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '400 COLLEGE ST',
#   'SchoolCity': 'TAFT',
#   'SchoolState': 'TX',
#   'SchoolZip': '78390-2903',
#   'SchoolSiteStreetAddress': '727 MCINTYRE AVE',
#   'SchoolSiteCity': 'TAFT',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78390-2903',
#   'SchoolPhone': '(361) 528-2636 ext:2321',
#   'SchoolFax': '(361) 528-5477',
#   'SchoolEmailAddress': 'rtrevino@taftisd.net',
#   'SchoolWebPageAddress': '',
#   'SchoolPrincipal': 'MR RICARDO TREVINO   ',
#   'GradeRange': "'06-08",
#   'SchoolEnrollmentasofOct2014': '247',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'AddressRangeInterpolation',
#   'Latitude': '27.98444995',
#   'Longitude': '-97.38984462'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f11b'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205905",
#   'DistrictName': 'ODEM-EDROY ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '1 OWL SQ',
#   'DistrictCity': 'ODEM',
#   'DistrictState': 'TX',
#   'DistrictZip': '78370',
#   'DistrictSiteStreetAddress': '1 OWL SQ',
#   'DistrictSiteCity': 'ODEM',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78370',
#   'DistrictPhone': '(361) 368-8121 ext:223 ',
#   'DistrictFax': '(361) 368-2879',
#   'DistrictEmailAddress': 'gonzalesl@oeisd.org',
#   'DistrictWebPageAddress': 'www.oeisd.org',
#   'DistrictSuperintendent': 'MRS LISA ANE GONZALES   ',
#   'DistrictEnrollmentasofOct2014': '1007',
#   'SchoolNumber': "'205905041",
#   'SchoolName': 'ODEM J H',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '1 OWL SQ',
#   'SchoolCity': 'ODEM',
#   'SchoolState': 'TX',
#   'SchoolZip': '78370',
#   'SchoolSiteStreetAddress': '1 OWL SQ',
#   'SchoolSiteCity': 'ODEM',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78370',
#   'SchoolPhone': '(361) 368-8661 ext:244 ',
#   'SchoolFax': '(361) 368-2033',
#   'SchoolEmailAddress': 'branniganj@oeisd.org',
#   'SchoolWebPageAddress': 'www.oeisd.org',
#   'SchoolPrincipal': 'MR JAMES BRANNIGAN   ',
#   'GradeRange': "'06-08",
#   'SchoolEnrollmentasofOct2014': '221',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.948805',
#   'Longitude': '-97.591468'},
#  {'_id': ObjectId('65dd33e5f86f6bc84f06f11d'),
#   'CountyNumber': "'205",
#   'CountyName': 'SAN PATRICIO COUNTY',
#   'RegionNumber': "'02",
#   'DistrictNumber': "'205907",
#   'DistrictName': 'TAFT ISD',
#   'DistrictType': 'INDEPENDENT',
#   'DistrictStreetAddress': '400 COLLEGE ST',
#   'DistrictCity': 'TAFT',
#   'DistrictState': 'TX',
#   'DistrictZip': '78390-2702',
#   'DistrictSiteStreetAddress': '400 COLLEGE ST',
#   'DistrictSiteCity': 'TAFT',
#   'DistrictSiteState': 'TX',
#   'DistrictSiteZip': '78390-2702',
#   'DistrictPhone': '(361) 528-2636 ext:2224',
#   'DistrictFax': '(361) 528-2223',
#   'DistrictEmailAddress': 'ncunningham@taftisd.net',
#   'DistrictWebPageAddress': 'www.taftisd.net',
#   'DistrictSuperintendent': 'DR NUGGET CUNNINGHAM   ',
#   'DistrictEnrollmentasofOct2014': '1110',
#   'SchoolNumber': "'205907101",
#   'SchoolName': 'WOODROE PETTY EL',
#   'InstructionType': 'REGULAR INSTRUCTIONAL',
#   'CharterType': '',
#   'SchoolStreetAddress': '400 COLLEGE ST',
#   'SchoolCity': 'TAFT',
#   'SchoolState': 'TX',
#   'SchoolZip': '78390-3016',
#   'SchoolSiteStreetAddress': '401 PEACH STREEET',
#   'SchoolSiteCity': 'TAFT',
#   'SchoolSiteState': 'TX',
#   'SchoolSiteZip': '78390-3016',
#   'SchoolPhone': '(361) 528-2636 ext:2622',
#   'SchoolFax': '(361) 528-2717',
#   'SchoolEmailAddress': 'jblankenship@taftisd.net',
#   'SchoolWebPageAddress': 'taftisd.net',
#   'SchoolPrincipal': 'JILL BLANKENSHIP   ',
#   'GradeRange': "'EE-05",
#   'SchoolEnrollmentasofOct2014': '533',
#   'SchoolStatus': 'Active',
#   'SchoolStatusDate': ' ',
#   'UpdateDate': '2015-03-14T05:35:23',
#   'GeocodeQualityType': 'Manual',
#   'Latitude': '27.969734',
#   'Longitude': '-97.402656'}]
